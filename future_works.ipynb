# %%
#importing libs
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading dataFrames
LT_df = pd.read_csv('LT_db.csv', index_col=0)
MT_df = pd.read_csv('MT_db.csv', index_col=0)
ST_df = pd.read_csv('ST_db.csv', index_col=0)
LT_df.head()
# Out:
#        1985      1986      1987      1988      1989      1990      1991  \
# 0  0.058991  0.053736  0.054029  0.049532  0.046935  0.042272  0.036797
# 1  0.019406  0.018572  0.022374  0.019060  0.017983  0.017754  0.017087
# 2  0.058017  0.058177  0.052692  0.050892  0.060750  0.036628  0.028642
# 3  0.025359  0.027203  0.026485  0.027291  0.026973  0.024987  0.026807
# 4  0.043743  0.039089  0.037226  0.035582  0.037794  0.034047  0.035227
#
#        1992      1993      1994  ...      2005      2006      2007      2008  \
# 0  0.019305  0.017075  0.015213  ...  0.010384  0.012528  0.016835  0.030447
# 1  0.016882  0.018164  0.011848  ...  0.040536  0.045441  0.049475  0.048730
# 2  0.016910  0.015798  0.013101  ...  0.030831  0.028432  0.028863  0.032398
# 3  0.028288  0.030391  0.030432  ...  0.034667  0.035496  0.034099  0.036516
# 4  0.033897  0.036342  0.038152  ...  0.030300  0.027975  0.026316  0.026567
#
#        2009      2010      2011      2012      2013      2014
# 0  0.047841  0.058194  0.081561  0.069264  0.062279  0.058989
# 1  0.050762  0.051160  0.051513  0.054701  0.051558  0.053060
# 2  0.032645  0.034456  0.039370  0.036951  0.038180  0.043191
# 3  0.037784  0.038403  0.037763  0.040068  0.038719  0.040476
# 4  0.025392  0.022513  0.022134  0.023095  0.022215  0.027458
#
# [5 rows x 30 columns]

# %%
LT_values = LT_df.values[:-1]
Population_LT = LT_df.values[-1]

# %%
plt.figure(figsize=(16, 8))
plt.scatter(np.arange(0, len(LT_values.ravel())), LT_values.ravel(), 1)
plt.legend(['LT group of countries'])
plt.axhline(0.065, color='orange')
plt.axhline(0.05, color='orange')
plt.axhline(0.01, color='orange')
plt.yticks(np.arange(0, 0.1, 0.01))
plt.ylabel('values')
plt.xlabel('points')
plt.show()

# %%
MT_values = MT_df.values[:-1]
Population_MT = MT_df.values[-1]

# %%
plt.figure(figsize=(16, 8))
plt.scatter(np.arange(0, len(MT_values.ravel())), MT_values.ravel(), 1)
plt.legend(['MT group of countries'])
plt.axhline(0.06, color='orange')
plt.axhline(0.01, color='orange')
plt.yticks(np.arange(0, 0.1, 0.01))
plt.ylabel('values')
plt.xlabel('points')
plt.show()

# %%
ST_values = ST_df.values[:-1]
Population_ST = ST_df.values[-1]

# %%
plt.figure(figsize=(16, 8))
plt.scatter(np.arange(0, len(ST_values.ravel())), ST_values.ravel(), 1)
plt.legend(['LT group of countries'])
plt.axhline(0.07, color='orange')
plt.axhline(0.02, color='orange')
plt.yticks(np.arange(0, 0.1, 0.01))
plt.ylabel('values')
plt.xlabel('points')
plt.show()
